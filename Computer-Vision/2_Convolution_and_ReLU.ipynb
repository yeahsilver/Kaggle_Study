# %% [markdown]
# # 2. Convolution and ReLU
# ## Introduction
# - 이미지를 분류할 때 주로 사용하는 layer
#   - convolutional layer with ReLU activation
#   - maximum pooling layer
# - 해당 챕터에서는 ReLU activation에 관하여 알아볼 예정

# %% [markdown]
# ## Feature Extraction
# ##### 3개의 기본 연산으로 특징 추출을 진행함
# - 특정 특징에 대한 이미지를 **필터링** (covolution)
# - 필터링된 이미지로부터 특징을 **탐지**
# - 특징 강화를 위해 이미지를 **압축**

# %% [markdown]
# ![스크린샷 2022-07-13 오전 10.08.48.png](data:image/png;base64,...)

# %% [markdown]
# ## Filter with Convolution
# > convolutional layer의 경우 필터링 과정이 수반됨

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Conv2D(filters=64, kernel_size=3),
    # More layers follow
])

# %% [markdown]
# ## Weights
# - 훈련 중에 convnet가 학습하는 weight는 주로 convolutional layer에 포함된다.
# - 해당 weight를 **kernel**이라고 명명하고, 작은 배열로 나타낼 수 있음
# - **kernel**은 이미지를 스캔하여 픽셀의 가중치 합계를 생성하며 작동한다.
